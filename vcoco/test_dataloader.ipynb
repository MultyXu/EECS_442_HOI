# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/EECS 442 final project/v-coco"
# %cd "/content/drive/MyDrive/EECS 442 final project/EECS_442_HOI/vcoco"
# %cd "/content/drive/MyDrive/Colab Notebooks/EECS 442 final project/v-coco"


# %cd "/content/drive/MyDrive/Colab Notebooks/EECS_442_HOI/vcoco"
# Out:
# /content/drive/.shortcut-targets-by-id/12okk2Fd14qMDV5jRdlZ838Uf8WQjaIS6/EECS_442_HOI/vcoco

# %%
from dataloader_change import get_train_val_test_loaders
from matplotlib import pyplot as plt

# %%
va = get_train_val_test_loaders(20)
    #print("Val:\t", len(va.X))
# Out:
# <class 'list'>
# ...

# %%
for i ,(X, y) in enumerate(va):
# print(X.shape)
# print(y.shape)
# plt.imshow(X)
# print(X[0])

  plt.figure()
  plt.imshow(X[0].int())
  plt.plot(y[0][0], y[0][1], marker='.', markersize=20)
